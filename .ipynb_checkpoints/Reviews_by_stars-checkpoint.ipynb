# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from scipy.stats import kendalltau
from pylab import rcParams
import pymysql
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
def call_mysql():
    con = False
    rows = np.nan
    try:
        con = pymysql.connect(host='localhost', port=3307, user='root', passwd='', db='ortho')
        with con:
            cur = con.cursor()
            #myvalues = "'" + yelp_id+"'," + str(stars) + "," + str(reviews) + "," + "1"
            sql = 'USE ortho;'
            cur.execute(sql)
            sql = 'SELECT stars,nreviews FROM business;' 
            #print(sql)
            cur.execute(sql)
            rows = cur.fetchall()
#             for row in rows:
#                 print(row)
    except pymysql.Error, e:
        print "Error %d: %s" % (e.args[0],e.args[1])
        sys.exit(1)
    finally:
        if con:
            con.close()
    return rows

# %%
def seaborn_graph(array):
    print('My first graph\n')
    sns.set(style="ticks")
    
    x = array[:,0]
    y = np.log(array[:,1])
    
    fig = sns.jointplot(x, y, kind="hex", stat_func=kendalltau, color="#008A00")
    #ax = plt.axes()
    
    fig.set_axis_labels('Stars','Reviews (log)', fontsize=30)
    #plt.set_xticklabels([np.array(1,5,.5)])
    #plt.set_xticklabels(np.array(1,5,.5))
    #plt.setp([ax.get_xticklabels()], fontsize=12)
    plt.show()

# %%
def scatterplot_graph(array):
    
    x = array[:,0]
    y = np.log(array[:,1])
    
    print 'shapes: ',np.shape(x), np.shape(y)
    print 'types: ',len(x), len(y)
    print np.shape(x[:]), np.shape(y[:])
    
    width = [min(x),np.ceil(max(x))]
    
    fig = plt.figure(figsize = (5,5))
    ax = plt.axes()
    fig = plt.plot(x, y, marker='d', ms=8, mew=.5,lw=0)
    
    plt.setp([ax.set_ylabel('Reviews (log)'),ax.set_xlabel('Stars')],fontsize=16)
    
    # Calculate and plot a regression line for each group
    regr = linear_model.LinearRegression(fit_intercept=True, normalize=True,copy_X=True)
    regr.fit(x.T,y.T,1)
    plt.plot(width, regr.predict(width), color = c, lw=1)
    
    
    ax.margins(0.05)
# Out:
#   File "<ipython-input-56-ff6ff9a17bf9>", line 8
#     print np.shape(x[:][]), np.shape(y[:][])
#                         ^
# SyntaxError: invalid syntax

# %%
def main():
    data = call_mysql()
    df = np.array([])
    
    #ultimate solution mysql-> DF is probably this
    #df = pd.read_sql
    
    for d in data:
        #print(d)
        df = np.append(df, d, axis=0)
    rows = np.size(df)/2
    #print(rows)
    df = np.reshape(df,(rows,2))
    #print(df)
    
    seaborn_graph(df)
    scatterplot_graph(df)
    
if __name__=='__main__':
    main()
# Out:
# My first graph
# shapes:  (287,) (287,)
# types:  287 287
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-2d5eb48d4e4e> in <module>()
#      18
#      19 if __name__=='__main__':
# ---> 20     main()
#
# <ipython-input-57-2d5eb48d4e4e> in main()
#      15
#      16     seaborn_graph(df)
# ---> 17     scatterplot_graph(df)
#      18
#      19 if __name__=='__main__':
#
# <ipython-input-54-580dac15242b> in scatterplot_graph(array)
#       6     print 'shapes: ',np.shape(x), np.shape(y)
#       7     print 'types: ',len(x), len(y)
# ----> 8     print np.shape(x[0][:]), np.shape(y[:][0])
#       9
#      10     width = [min(x),np.ceil(max(x))]
#
# IndexError: invalid index to scalar variable.
